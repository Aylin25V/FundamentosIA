# %% [markdown]
# ## Laboratorio 1
#
# # 01/09/2026
#
# # Aylin

# %%
print ("Mi primer sistema inteligente")
nombre = input("Escriba su nombre empezando por apellido paterno")
matricula = input("Escribe tu matricula")
promedio = float(input("Escribe tu calificación"))
# Out:
# Mi primer sistema inteligente
# Escriba su nombre empezando por apellido paterno Vargas Ramos Aylin
# Escribe tu matricula 20243L601033
# Escribe tu calificación 9.5

# %%
print ("Datos almacenados")
print ("Nombre:", nombre)
print ("Matricula:", matricula)
print ("Promedio:", promedio)
# Out:
# Datos almacenados
# Nombre: Vargas Ramos Aylin
# Matricula: 20243L601033
# Promedio: 9.5

# %%
# Reglas
if promedio>=8.0 and promedio <=10:
    print("Excelente desempeño")
elif promedio<8.0 and promedio>=7.0:
    print("Vas a reprobar pronto")
elif promedio<7.0 and promedio>6.0:
    print("Medícate")
else:
    print("Reprobaste, ya date de baja")
# Out:
# Excelente desempeño
