# %% [markdown]
# ### Lab 4: Proposiciones 2
# ### **Objetivo:** Analizar un problema de IA, identificar el conocimiento relevante, representarlo
# ### mediante proposiciones y construir una expresión lógica que permita al sistema tomar una decisión

# %% [markdown]
# ### Proposiciones
# ##P: El servidor principal está disponible
# ##Q: La latencia supera el límite establecido
# ##R: La pérdida de paquetes supera el límite permitido
# ##S: El tráfico de red es anormalmente alto
# ##T: El servidor de respaldo está disponible
# ##U: El sistema de monitoreo está activo

# %%
## Definición de variables
servidorDisponible = False
latenciaAlta = True
perdidaAlta = True
traficoAlto = True
respaldoDisponible = False
monitoreoActivo = True

# %%
existeCondicion = (servidorDisponible  and latenciaAlta and perdidaAlta and traficoAlto and respaldoDisponible and monitoreoActivo)

# %%
print ("¿Existe una condición crítica?", existeCondicion)
# Out:
# ¿Existe una condición crítica? False

# %%
print (" == Condición Crítica ==")
print ("Development by Aylin")

servidorDisponible = input ("¿El servidor principal está disonible? (s/n):").lower() == "n"
latenciaAlta = input ("¿La latencia es alta? (s/n):").lower() == "s"
perdidaAlta = input ("¿La pérdida de paquetes es alta? (s/n):").lower() == "s"
traficoAlto = input ("¿El tráfico es anormalmente alto? (s/n):").lower() == "s"
respaldoDisponible = input ("¿El servidor de respaldo está disponible? (s/n):").lower() == "n"
monitoreoActivo = input ("¿El sistema de monitoreo está activo? (s/n):").lower() == "s"

existeCondicion = (servidorDisponible and latenciaAlta and perdidaAlta and traficoAlto and respaldoDisponible and monitoreoActivo)

print ("Condición Existente")
if existeCondicion == True:
    print ("Existe una condición crítica")
else:
    print ("No existe una condición crítica")
# Out:
#  == Condición Crítica ==
# Development by Aylin
# ¿El servidor principal está disonible? (s/n): s
# ¿La latencia es alta? (s/n): s
# ¿La pérdida de paquetes es alta? (s/n): s
# ¿El tráfico es anormalmente alto? (s/n): s
# ¿El servidor de respaldo está disponible? (s/n): s
# ¿El sistema de monitoreo está activo? (s/n): s
# Condición Existente
# No existe una condición crítica
